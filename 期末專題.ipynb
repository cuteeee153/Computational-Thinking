# %% [markdown]
# <a href="https://colab.research.google.com/github/cuteeee153/Computational-Thinking/blob/master/%E6%9C%9F%E6%9C%AB%E5%B0%88%E9%A1%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 分組名單:
#
# 企管三甲 黃綉琳
#
# 分工:組長、早餐腳本撰寫、程式碼撰寫
#
# 企管三甲 廖丞軒
#
# 分工:午餐腳本撰寫
#
# 企管三甲 張丞妤
#
# 分工:晚餐腳本撰寫、程式碼撰寫
#
# 企管三甲 陳凱威
#
# 分工:飲料腳本撰寫、程式碼撰寫

# %% [markdown]
# A107270030 企管三甲 黃綉琳
#
# 哈囉!你好,這邊是幫你選擇三餐機器人，我是早餐機器人，很高興認識你。
#
# 我只能接受很簡單的答案，請依提問回答，不然就會讀不出來。
#
# 貼心提醒您，此機器人生性暴躁，玻璃心誤入
#
# 請問你的大名是:小黃
#
# 你好阿!小黃，很高興認識你
#
# 我可以幫你選擇早餐吃甚麼，你知道早餐要吃甚麼了嗎?知道/不知道
#
# 那就不需要我囉，別來亂啦!/那你還知道甚麼?只好讓我來幫助你了
#
#
#
# 情境1
#
# 想先問你，你會不會很餓?會
#
# 看來是食量很大的朋友呢
#
# 那你比較喜歡吃吐司，漢堡還是鐵板麵?
#
# 吐司
#
# 真沒創意
#
# 想再問你喜歡甚麼口味的呢?巧克力，花生，奶酥?
#
# /巧克力:會變胖ㄟ!但你應該沒差!那今天就吃巧克力厚片吧!
#
# /花生 :會變胖ㄟ!但你應該沒差!那今天就吃花生厚片吧!
#
# /奶酥 :會變胖ㄟ!但你應該沒差!那今天就吃奶酥厚片吧!
#
# ------------------------------------------------------------
#
#  漢堡 :
#
# 看來你真的很餓呢
#
#  那妳喜歡甚麼口味的呢?卡拉雞，嫩切雞，里肌，
#
# /卡拉雞:那今天就吃卡拉雞腿堡吧!肯德基歡迎你
#
# /嫩切雞 :那今天就吃嫩切雞腿堡吧!肯德基歡迎你
#
# /里肌 :聽起來很不可口，但看在你喜歡的份上就吃里肌漢堡吧!
#
# ------------------------------------------------------------
#
#  鐵板麵 :
#
#   哇!我也喜歡吃鐵板麵呢!
#
#  那妳喜歡甚麼口味的呢?胡椒，蘑菇，肉醬
#
# /胡椒:好選擇!感覺就能吃很飽!那今天就吃胡椒鐵板麵吧!
#
# /蘑菇 :好選擇!感覺就能吃很飽!那今天就吃蘑菇鐵板麵吧!
#
# /肉醬:好選擇!感覺就能吃很飽!那今天就吃義大利肉醬麵吧!
#
#
#
# 情境2
#
# 想先問你，你會不會很餓?不會
#
# 不要再假裝小鳥胃了!
#
# 好吧，喜歡吃吐司，蛋餅還是其他小東西?
#
# 吐司:
#
#     哇!好沒創意
#
#    那妳喜歡甚麼口味的呢?巧克力，花生，奶酥
#
#    /巧克力:小心會變胖!但你應該不在乎!那今天就吃巧克力薄片吧!
#
#    /花生 :小心會變胖!但你應該不在乎!那今天就吃花生薄片吧!
#
#    /奶酥 :小心會變胖!但你應該不在乎!那今天就吃奶酥厚片吧!
#
# -------------------------------------------------------------
#
#   蛋餅:
#
#     早餐店就是要吃蛋餅阿
#
#    那妳喜歡甚麼口味的呢?玉米，起司，火腿
#
#     /玉米:好選擇!我的必點名單!那今天就吃玉米蛋餅吧!
#
#     /起司 :好選擇!融化起司最對味!那今天就吃火腿蛋餅吧!
#
#     /火腿 :好選擇!早餐店必吃!那今天就吃火腿蛋餅吧!
#
# ---------------------------------------------------------------
#
#   其他炸物:
#
#     有夠不健康
#
#    那這三樣中挑一個你最喜歡的!薯餅，薯條，雞塊
#
#    /薯餅:那今天就吃薯餅吧!但還是不要太常吃炸的喔!
#
#    /薯條 :那今天就吃薯條吧!但還是不要太常吃炸的喔!
#
#    /雞塊 :那今天就吃雞塊吧!但還是不要太常吃炸的喔!

# %%
print("哈囉!你好,這邊是幫你選擇三餐機器人，我是早餐機器人")
note = "我只能接受很簡單的答案，請依提問回答，不然就會讀不出來!"
print(note)
other = "(貼心提醒:此機器人生性暴躁，玻璃心誤入)"
print(other)
name = input("請問你的大名是:")
print("我叫",name)
print("你好阿!",name,"很高興認識你")
answer = input("知道早餐要吃甚麼嗎:")
#情境1
if answer == "知道":                   
  print('那就不需要我囉，別來亂拉!') 
#情境2
elif answer == "不知道":                 
  print("那你還知道甚麼?只好讓我來幫助你了")
#情境2-1
  answer = input("你會不會很餓:")
if answer== "會":
  print("看來是食量很大的朋友呢")
#情境2-1問題
  answer = input("喜歡吃吐司，漢堡還是鐵板麵:")
#情境2-1回答1
if answer== "吐司":
  print("真沒創意")
#情境2-1問題1
  answer = input("那你喜歡甚麼口味的呢?巧克力，花生，奶酥")
if answer== "巧克力":
  print("會變胖ㄟ!但你應該沒差!那今天就吃巧克力厚片吧!")
elif answer == "花生" :
  print("會變胖ㄟ!但你應該沒差!那今天就吃花生厚片吧!")
elif answer == "奶酥" :
  print("會變胖ㄟ!但你應該沒差!那今天就吃奶酥厚片吧!")
#情境2-1回答2
elif answer == "漢堡" :
  print("看來你真的很餓呢")
#情境2-1問題2
  answer = input("那妳喜歡甚麼口味的呢?卡拉雞，嫩切雞，里肌，")
if answer== "卡拉雞":
  print("那今天就吃卡拉雞腿堡吧!肯德基歡迎你")
elif answer == "嫩切雞" :
  print("那今天就吃嫩切雞腿堡吧!肯德基歡迎你")
elif answer == "里肌" :
  print("聽起來很不可口，但看在你喜歡的份上就吃里肌漢堡吧!")
#情境2-1回答3
elif answer == "鐵板麵" :
  print("哇!我也喜歡吃鐵板麵呢!")
#情境2-1問題3
  answer = input("那妳喜歡甚麼口味的呢?胡椒，蘑菇，肉醬")
if answer== "胡椒":
  print("好選擇!感覺就能吃很飽!那今天就吃胡椒鐵板麵吧!")
elif answer == "蘑菇" :
  print("好選擇!感覺就能吃很飽!那今天就吃蘑菇鐵板麵吧!")
elif answer== "肉醬":
  print("好選擇!感覺就能吃很飽!那今天就吃義大利肉醬麵吧!")
#情境2-2
elif answer == "不會":
  print("不要再假裝小鳥胃了!")
#情境2-2問題
  answer = input("好吧，喜歡吃吐司，蛋餅還是其他小東西:")
#情境2-1回答1
  if answer== "吐司":
    print("哇!好沒創意")
#情境2-2問題1
    answer = input("那妳喜歡甚麼口味的呢?巧克力，花生，奶酥")
    if answer== "巧克力":
      print("小心會變胖!但你應該不在乎!那今天就吃巧克力薄片吧!")
    elif answer == "花生" :
      print("小心會變胖!但你應該不在乎!那今天就吃花生薄片吧!")
    elif answer == "奶酥" :
      print("小心會變胖!但你應該不在乎!那今天就吃奶酥厚片吧!")
#情境2-1回答2
  if answer== "蛋餅":
    print("早餐店就是要吃蛋餅阿")
#情境2-2問題2
    answer = input("那妳喜歡甚麼口味的呢?玉米，起司，火腿")
    if answer== "玉米":
      print("好選擇!我的必點名單!那今天就吃玉米蛋餅吧!")
    elif answer == "起司" :
      print("好選擇!融化起司最對味!那今天就吃火腿蛋餅吧!")
    elif answer == "火腿" :
      print("好選擇!早餐店必吃!那今天就吃火腿蛋餅吧!")
#情境2-1回答3
  if answer== "其他炸物":
    print("有夠不健康")
#情境2-2問題3
    answer = input("那這三樣中挑一個你最喜歡的!薯餅，薯條，雞塊")
    if answer== "薯餅":
      print("那今天就吃薯餅吧!但還是不要太常吃炸的喔!")
    elif answer == "薯條" :
      print("那今天就吃薯條吧!但還是不要太常吃炸的喔!")
    elif answer == "雞塊" :
      print("那今天就吃雞塊吧!但還是不要太常吃炸的喔!")
# Out:
# 哈囉!你好,這邊是幫你選擇三餐機器人，我是早餐機器人
# 我只能接受很簡單的答案，請依提問回答，不然就會讀不出來!
# (貼心提醒:此機器人生性暴躁，玻璃心誤入)
# 請問你的大名是:小綉
# 我叫 小綉
# 你好阿! 小綉 很高興認識你
# 知道早餐要吃甚麼嗎:不知道
# 那你還知道甚麼?只好讓我來幫助你了
# 你會不會很餓:會
# 看來是食量很大的朋友呢
# 喜歡吃吐司，漢堡還是鐵板麵:漢堡
# 看來你真的很餓呢
# 那妳喜歡甚麼口味的呢?卡拉雞，嫩切雞，里肌，嫩切雞
# 那今天就吃嫩切雞腿堡吧!肯德基歡迎你

# %% [markdown]
# A107270052 企管三甲 廖丞軒
#
# "哈囉!你好,這邊是幫你選擇三餐機器人，我是午餐機器人，很高興認識你"
#  "我只能接受很簡單的答案，請依提問回答，不然就會讀不出來!"
# "(貼心提醒:此機器人生性暴躁，請小心)"
# "請問你的大名是:"
# "我叫",小咻
# "你好阿!小咻
# "知道早餐要吃甚麼嗎:"
# #情境一
#  "知道":
# '那我就不推薦囉
#  "不知道"
# "好的!讓我來幫幫你"
# #情境二之一
# "你會不會很餓:"
# "會"
# "看起來食量蠻大的"
# "喜歡吃便當，速食還是便利商店:"
# #情境二之一回答1
# "便當
# "真沒意思"
# #情境二之一問題1
# "那你喜歡甚麼便當呢?油雞販，叉燒飯，燒肉飯"
# "油雞販":
# "好阿!吃飽一點!那今天就吃油雞飯吧!"
#  "叉燒飯" :
# "好阿!吃飽一點!那今天就吃叉燒飯吧!"
#  "燒肉飯" :
# "好阿!吃飽一點!那今天就吃燒肉飯吧!"
# #情境二之一回答2
# "速食"
# "看來你真的很餓呢"
# #情境二之一問題2
# "那妳喜歡甚麼口味的呢?漢堡，雞塊，雞翅，"
# 漢堡
# "那今天就吃漢堡吧!推薦麥當勞!"
# "雞塊"
# "那今天就吃雞塊吧!麥當勞歡迎你!"
#  "雞翅"
# "那今天就吃雞翅吧!麥當勞歡迎你!"
# #情境二之一回答3
# "便利商店" :
# "哇!便利商店比較不健康呢!"
# #情境二之一問題3
# "那妳喜歡甚麼呢?泡麵，咖哩飯，關東煮"
# "泡麵":
# "天氣冷!吃這歌剛剛好!那今天就吃泡麵吧!"
# "咖哩飯"
# "讚唷!這能吃很飽!那今天就吃咖哩飯吧!"
# "關東煮":
# "水喔!吃下去身體都能暖和了!那今天就吃關東煮吧!"
# #情境一回答
#  "不會":
# "確定餒!那就不推薦囉!"

# %%
print("哈囉!你好,這邊是幫你選擇三餐機器人，我是午餐機器人，很高興認識你")
note = "我只能接受很簡單的答案，請依提問回答，不然就會讀不出來!"
print(note)
other = "(貼心提醒:此機器人生性暴躁，請小心)"
print(other)
name = input("請問你的大名是:")
print("我叫",name)
print("你好阿!",name,)
answer = input("知道早餐要吃甚麼嗎:")
#情境一
if answer == "知道":
  print('那我就不推薦囉:)') 
#情境二
elif answer == "不知道":
  print("好的!讓我來幫幫你")
#情境二之一
  answer = input("你會不會很餓:")
if answer== "會":
  print("看起來食量蠻大的")
#情境二之一問題 
  answer = input("喜歡吃便當，速食還是便利商店:")
#情境二之一回答1
if answer== "便當":
  print("真沒意思")
#情境二之一問題1
  answer = input("那你喜歡甚麼便當呢?油雞販，叉燒飯，燒肉飯")
if answer== "油雞販":
  print("好阿!吃飽一點!那今天就吃油雞飯吧!")
elif answer == "叉燒飯" :
  print("好阿!吃飽一點!那今天就吃叉燒飯吧!")
elif answer == "燒肉飯" :
  print("好阿!吃飽一點!那今天就吃燒肉飯吧!")
#情境二之一回答2
elif answer == "速食" :
  print("看來你真的很餓呢")
#情境二之一問題2  
  answer = input("那妳喜歡甚麼口味的呢?漢堡，雞塊，雞翅，")
if answer== "漢堡":
  print("那今天就吃漢堡吧!推薦麥當勞!")
elif answer == "雞塊" :
  print("那今天就吃雞塊吧!麥當勞歡迎你!")
elif answer == "雞翅" :
  print("那今天就吃雞翅吧!麥當勞歡迎你!")
#情境二之一回答3
elif answer == "便利商店" :
  print("哇!便利商店比較不健康呢!")
#情境二之一問題3  
  answer = input("那妳喜歡甚麼呢?泡麵，咖哩飯，關東煮")
if answer== "泡麵":
  print("天氣冷!吃這歌剛剛好!那今天就吃泡麵吧!")
elif answer == "咖哩飯" :
  print("讚唷!這能吃很飽!那今天就吃咖哩飯吧!")
elif answer== "關東煮":
  print("水喔!吃下去身體都能暖和了!那今天就吃關東煮吧!")
#情境一回答
elif answer == "不會":
  print("確定餒!那就不推薦囉!")

# %% [markdown]
# A107270270 企管三甲 張丞妤
#
# 哈囉～我是晚餐機器人很高興為你服務！
# 貼心服務讓你一次滿足
# 由於設計者愛吃海底撈火鍋所以主要為此設計的喔！
# 最近天氣好冷喔～你有想吃什麼晚餐嗎？
# 你想吃火鍋嗎！我也推薦你吃火鍋暖暖身體喔～
# 想要吃哪一家的火鍋呢？！
# 海底撈（單點）
#
# 你想吃海底撈是嗎是嗎～
# 我也很喜歡吃海底撈呢！特別是他的服務和湯底，真懂吃～
#
# 那你的湯底想要選哪種呢？
# /蕃茄湯底：愛吃番茄的人真的是必吃啊啊啊！健康又補血喔～
# /三鮮湯底：口感鮮香濃郁呢～不想要太膩這款最剛好喔～
# /麻辣湯底：愛吃辣的人就是要選這款啊！保證辣到你～
#
# 那你要搭配哪種肉呢？
# /牛肉建議你放下去8秒鐘就可以拿起來囉！
# /豬肉建議你煮久一點才不會拉肚子喔！
# /羊肉建議你煮久一點，我們家的羊肉不太會有羊騷味喔～很好吃的
#
# 那你的主食要吃社呢？
# /白飯：香甜可口的一粒粒米絕對是你最好的選擇！
# /撈麵：我們家的招牌之一呢！還可以把麵DIY做餃子吃喔～
#
# 吃了這麼多你吃飽了嗎？！
# /吃得好飽喔～快要睡著了請幫我買單吧！今天的服務還滿意嗎~,很開心認識妳喔!期待你的下次光臨
# /這些才小case啦我還能吃很多很多挑戰極限喔~那我們繼續下一道菜吧~

# %%
print ("哈囉～我是晚餐機器人很高興為你服務！貼心服務讓你一次滿足")
hobby = "由於設計者愛吃海底撈火鍋所以主要為此設計的喔！最近天氣好冷喔～你有想吃什麼晚餐嗎？你想吃火鍋嗎！我也推薦你吃火鍋暖暖身體喔～"
print(hobby)

name=input("你好,請問大名是?:")
print(name,"很高興認識你!")

choose=input("想要吃哪一家的火鍋呢？！:")
print()

print("你想吃海底撈是嗎是嗎～我也很喜歡吃海底撈呢！特別是他的服務和湯底，真懂吃～")

soup_list=["蕃茄湯底","三鮮湯底","麻辣湯底"]
print("湯底選項",soup_list)

#問題一
answer=input("那你想要吃蕃茄湯底,三鮮湯底,麻辣湯底呢?:")
if answer=="蕃茄湯底":
    print("愛吃番茄的人真的是必吃啊啊啊！健康又補血喔～")
elif answer=="三鮮湯底":
    print("口感鮮香濃郁呢～不想要太膩這款最剛好喔～")
elif answer=="麻辣湯底":
    print("愛吃辣的人就是要選這款啊！保證辣到你～")

#問題二
meat_list=["牛肉","豬肉","羊肉"]
print("肉類選項",meat_list)
answer=input("那你想要吃牛肉,豬肉,羊肉呢?:")
if answer=="牛肉":
    print("建議你放下去8秒鐘就可以拿起來囉！")
elif answer=="豬肉":
    print("建議你煮久一點才不會拉肚子喔！")
elif answer=="羊肉":
    print("建議你煮久一點，我們家的羊肉不太會有羊騷味喔～很好吃的")

#問題三
staplefood_list=["白飯","撈麵"]
print("主食選項",staplefood_list)
answer=input("那今天主食想要吃白飯還是撈麵呢?~")
if answer=="白飯":
    print("香甜可口的一粒粒米絕對是你最好的選擇！")
elif answer=="撈麵":
    print("我們家的招牌之一呢！還可以把麵DIY做餃子吃喔～")

#問題四
full_list=["吃的很飽了","還沒吃飽"]
print("飽了沒",full_list)
answer=input("你吃的很飽了嗎～還是還沒吃飽呢?")
if answer=="吃的很飽了":
    print("吃得好飽喔～快要睡著了請幫我買單吧!")
    print("今天的服務還滿意嗎~,很開心認識你喔!期待你的下次光臨")
elif answer=="還沒吃飽":
    print("這些才小case啦我還能吃很多很多挑戰極限喔～")
    print("那我們繼續下一道菜吧~")

# %% [markdown]
# a107270277 企管三甲 陳凱威
#
# 哈囉你好！我是飲料機器人很高興為你服務
#
# 由於設計者喜愛喝飲料所以主要為此設計的喔
#
# 你好，你的大名是？！
#
# 很高興認識你
#
# 你想喝哪間飲料店呢？
#
# 可不可
#
# 你想喝可不可是嗎～我也很喜歡喝可不可！
#
# 你想要的是哪一種紅茶呢？
#
# 有茶味濃郁帶果香的——熟成紅茶
#
# 有絲絨般的蜜桃果香——胭脂紅茶
#
# 有冰淇淋與紅茶綿綿情意的——雪藏紅茶
#
# 雪藏紅茶
#
# 那你想不想加白玉珍珠、黑玉珍珠呢？
# 白玉珍珠

# %%
print ("哈囉～我是飲料機器人很開心為你服務")
hobby = "由於設計者喜愛喝飲料所以主要為此設計的喔"
print(hobby)
name=input("你好,請問大名是?！:")
print(name,"很高興認識你！")
choose=input("想喝哪間飲料店呢？！:")
print()
print("你想喝可不可是嗎～我也很喜歡喝可不可！")
blacktea_list=["熟成紅茶","胭脂紅茶","雪藏紅茶"]
print("紅茶選項",blacktea_list)
choose2=input("那你想要選擇哪種紅茶？:")
print(blacktea_list[0])
print(blacktea_list[0],":有茶味濃郁帶果香的")
print(blacktea_liat[1],":有絲絨般的蜜桃果香")
print(blacktea_list[2],":有冰淇淋與紅茶綿綿情意")
pearl_list["白玉珍珠","黑玉珍珠"]
print("珍珠選項",pearl_list)
choose3=input("今天想要搭配哪種珍珠呢？")
